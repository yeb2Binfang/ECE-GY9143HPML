# %% [markdown]
# <a href="https://colab.research.google.com/github/yeb2Binfang/ECE-GY9143HPML/blob/main/Pytorch/3_activation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %%
# fake data
x = torch.linspace(-5, 5, 200) # data (tensor), shape = (100, 1), the interval is 5
x = Variable(x)
x_np = x.data.numpy() # numpy array for plotting

# %%
# following are popular activation functions
y_relu = torch.relu(x).data.numpy()
y_sigmoid = torch.sigmoid(x).data.numpy()
y_tanh = torch.tanh(x).data.numpy()
y_softplus = F.softplus(x).data.numpy() # there is no softplus in torch
# y_softmax = torch.softmax(x, dim = 0).data.numpy() # softmax is a special kind of activatoin function, it is about probability

# %%
# plot to visualize these activation function
plt.figure(1, figsize = (8, 6))

plt.plot(x_np, y_relu, c='red', label = 'relu')
plt.plot(x_np, y_sigmoid, c='blue', label = 'sigmoid')
plt.plot(x_np, y_tanh, c='green', label = 'tanh')
plt.plot(x_np, y_softplus, c='black', label = 'softplus')
plt.ylim(-1, 6)
plt.legend(loc = 'best')
plt.grid()
